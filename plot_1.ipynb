# %% [markdown]
# <a href="https://colab.research.google.com/github/NMJ0/Cache_simulator/blob/main/plot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
associativities = [2, 4, 8, 16, 32, 64]  # Example associativity levels

# Replace these lists with your actual AAT data for each replacement policy
aat_policy1 = [3.5352, 3.0935, 2.9417,2.9457, 2.9652, 3.1485]
aat_policy2 = [3.5352, 3.0916,2.9467, 2.9541, 2.9387, 3.0926]
aat_policy3 = [3.7763, 3.4186,3.3520 ,3.3195, 3.3503 , 3.5150]
aat_policy4 = [3.7584, 3.4060,3.3172, 3.2661, 3.1695 , 3.3457 ]

edp_policy1 = [513915712.0000, 355784608.0000
, 323437760.0000, 326998848.0000 , 332028288.0000, 619911360.0000]
edp_policy2 = [513915712.0000, 355551744.0000, 324360224.0000, 327724544.0000,324877696.0000, 600465088.0000]
edp_policy3 = [577837376.0000,429186880.0000, 414996864.0000, 407597728.0000, 415760416.0000,735875392.0000]
edp_policy4 = [573222912.0000, 427468800.0000, 407811648.0000, 396475552.0000, 375098080.0000,  683959680.0000]

# Plotting
plt.figure(figsize=(12, 8))  # Increased figure size

plt.plot(associativities, aat_policy1, marker='o', label='LRU')
plt.plot(associativities, aat_policy2, marker='s', label='Pseudo LRU')
plt.plot(associativities, aat_policy3, marker='^', label='Random')
plt.plot(associativities, aat_policy4, marker='d', label='Round Robin')

# Adding titles and labels
plt.title('Average Access Time vs. Associativity for Different Replacement Policies \n (Cache Size = 1024)')
plt.xlabel('Associativity')
plt.ylabel('Average Access Time (ns)')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
associativities = [2, 4, 8, 16, 32, 64]  # Example associativity levels

# EDP data for each replacement policy
edp_policy1 = [513915712.0000, 355784608.0000, 323437760.0000, 326998848.0000, 332028288.0000, 619911360.0000]
edp_policy2 = [513915712.0000, 355551744.0000, 324360224.0000, 327724544.0000, 324877696.0000, 600465088.0000]
edp_policy3 = [577837376.0000, 429186880.0000, 414996864.0000, 407597728.0000, 415760416.0000, 735875392.0000]
edp_policy4 = [573222912.0000, 427468800.0000, 407811648.0000, 396475552.0000, 375098080.0000, 683959680.0000]

# Plotting
plt.figure(figsize=(12, 8))

plt.plot(associativities, edp_policy1, marker='o', label='LRU')
plt.plot(associativities, edp_policy2, marker='s', label='Pseudo LRU')
plt.plot(associativities, edp_policy3, marker='^', label='Random')
plt.plot(associativities, edp_policy4, marker='d', label='Round Robin')

# Adding titles and labels
plt.title('Energy-Delay Product vs. Associativity for Different Replacement Policies \n(Cache Size = 1024)')
plt.xlabel('Associativity')
plt.ylabel('Energy-Delay Product')
plt.legend()
plt.grid(True)

# Show plot
plt.show()
